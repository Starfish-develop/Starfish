# %% [markdown]
# How do we choose a reasonable range of slider values? Can this instead be just a flipper? Maybe there can be toggle button widgets which set the ranges of the sliders? Or maybe we can just regenerate the sliders using some more reasonable values.
#
# * Containers are useful to pull together many different widgets at once (Part 3)
#
# * show other widgets based upon values of others
#
# For example, if  $Z >=0 $, then $[\alpha/{\rm Fe}] = 0$.

# %%
# %matplotlib
import matplotlib.pyplot as plt
import numpy as np
from IPython.html import widgets # Widget definitions
from IPython.display import display, clear_output, HTML # Used to display widgets in the notebook
from IPython.html.widgets import interact, interactive, fixed
# Out:
# Using matplotlib backend: Qt4Agg

# %%
from StellarSpectra.model import Model
from StellarSpectra.spectrum import DataSpectrum
from StellarSpectra.grid_tools import TRES, HDF5Interface
import scipy.sparse as sp
import numpy as np

myDataSpectrum = DataSpectrum.open("../StellarSpectra/tests/WASP14/WASP-14_2009-06-15_04h13m57s_cb.spec.flux", orders=np.array([22]))
myInstrument = TRES()
myHDF5Interface = HDF5Interface("../libraries/PHOENIX_submaster.hdf5")

myModel = Model(myDataSpectrum, myInstrument, myHDF5Interface, stellar_tuple=("temp", "logg", "Z", "vsini", "vz", "logOmega"), 
                cov_tuple=("sigAmp", "logAmp", "l"), region_tuple=("h", "loga", "mu", "sigma"))
myOrderModel = myModel.OrderModels[0]
# Out:
# Grid stretches from 5135.32127896173 to 5236.2786948156
# wl_FFT is 0.04805860213977044 km/s
# Creating OrderModel 0

# %%
print("{", end="")
for sigma in myDataSpectrum.sigmas[0]:
    print(sigma, ", ", end="")
print("}", end="")
# Out:
# {4.15724768351e-15 , 4.09217768652e-15 , 4.21371810733e-15 , 4.17839930081e-15 , 4.16606340572e-15 , 4.14251099561e-15 , 4.20759507245e-15 , 4.15192755208e-15 , 4.14723023687e-15 , 4.24262843898e-15 , 4.11933202909e-15 , 4.12657767371e-15 , 4.16336859817e-15 , 4.1372859229e-15 , 4.13445334824e-15 , 4.17576794009e-15 , 4.08628299926e-15 , 4.18912464066e-15 , 4.15614209061e-15 , 4.06392189597e-15 , 4.03570322829e-15 , 4.06856299816e-15 , 4.07044699658e-15 , 3.9978339361e-15 , 4.04889697521e-15 , 4.08829594021e-15 , 4.0321747309e-15 , 4.10869908465e-15 , 4.15522207156e-15 , 4.1177723633e-15 , 4.07544845231e-15 , 4.05713897713e-15 , 4.0123236138e-15 , 4.10367032069e-15 , 3.99656832699e-15 , 3.94069709767e-15 , 3.84959067963e-15 , 3.91624402531e-15 , 4.00063902913e-15 , 3.94912037832e-15 , 3.75438902699e-15 , 3.54216327546e-15 , 3.41187119893e-15 , 3.47704846901e-15 , 3.57180632382e-15 , 3.85109009652e-15 , 3.81698138451e-15 , 3.60018205153e-15 , 3.21804350998e-15 , 3.03245430236e-15 , 3.22566167917e-15 , 3.5642506881e-15 , 3.7377721566e-15 , 3.93659000885e-15 , 3.91806701374e-15 , 3.91474555799e-15 , 3.95700144091e-15 , 3.85542466399e-15 , 3.91317424333e-15 , 3.92798253601e-15 , 3.91406399093e-15 , 3.99987734954e-15 , 3.9131451791e-15 , 3.93015142634e-15 , 3.87866555851e-15 , 3.89339282649e-15 , 3.87201193896e-15 , 3.9180847998e-15 , 3.94331384263e-15 , 3.94445899815e-15 , 3.86456137554e-15 , 3.91089689858e-15 , 3.87600660471e-15 , 3.8218431366e-15 , 3.93668365307e-15 , 3.87923846681e-15 , 3.81793632483e-15 , 3.83757411076e-15 , 3.85614343687e-15 , 3.75377799851e-15 , 3.81901338204e-15 , 3.78302588671e-15 , 3.84623908284e-15 , 3.80342746652e-15 , 3.82239699157e-15 , 3.66072177208e-15 , 3.36349289555e-15 , 2.99586612345e-15 , 2.61331489514e-15 , 2.76318589909e-15 , 2.87878700789e-15 , 2.79549855816e-15 , 2.5280043568e-15 , 2.51452658945e-15 , 2.81744273447e-15 , 3.24519374411e-15 , 3.50162606937e-15 , 3.58705747622e-15 , 3.68300001823e-15 , 3.76915205729e-15 , 3.80552264843e-15 , 3.8112711524e-15 , 3.77219927184e-15 , 3.77950350226e-15 , 3.71112725184e-15 , 3.7531908195e-15 , 3.82398972754e-15 , 3.77607265988e-15 , 3.83205638697e-15 , 3.78446901974e-15 , 3.74342756301e-15 , 3.75448875522e-15 , 3.62731797461e-15 , 3.73561861055e-15 , 3.75825499117e-15 , 3.65785524698e-15 , 3.71445086293e-15 , 3.71937689836e-15 , 3.69276938815e-15 , 3.7820729506e-15 , 3.63659611246e-15 , 3.63942110632e-15 , 3.58530621214e-15 , 3.68579367917e-15 , 3.65478178334e-15 , 3.71841987747e-15 , 3.67054727814e-15 , 3.66385342056e-15 , 3.69790793953e-15 , 3.6916174403e-15 , 3.67265531453e-15 , 3.59611414073e-15 , 3.54537382165e-15 , 3.63602771636e-15 , 3.60021954479e-15 , 3.67362095912e-15 , 3.58419880259e-15 , 3.62580032793e-15 , 3.5189316242e-15 , 3.3586430265e-15 , 3.15517809282e-15 , 3.0354590264e-15 , 3.22260919428e-15 , 3.39556228693e-15 , 3.46817932588e-15 , 3.56338858328e-15 , 3.56693798182e-15 , 3.57577983477e-15 , 3.55262030148e-15 , 3.60585673852e-15 , 3.57494024681e-15 , 3.61810136309e-15 , 3.50082045967e-15 , 3.49094896351e-15 , 3.46198140999e-15 , 3.33184092708e-15 , 3.04151642339e-15 , 2.84001208883e-15 , 2.82159408521e-15 , 2.96601272091e-15 , 3.1632285313e-15 , 3.15026767141e-15 , 3.09418359593e-15 , 2.9424181798e-15 , 2.91139694696e-15 , 2.77847153715e-15 , 2.66593624111e-15 , 2.83355966103e-15 , 3.26456952026e-15 , 3.35621055627e-15 , 3.51366085768e-15 , 3.45506648143e-15 , 3.46075177648e-15 , 3.47294729646e-15 , 3.4888453915e-15 , 3.4765147449e-15 , 3.53455769242e-15 , 3.49195581382e-15 , 3.43012949571e-15 , 3.4135383019e-15 , 3.46372758815e-15 , 3.44673165615e-15 , 3.37121345297e-15 , 3.4083429005e-15 , 3.39579292229e-15 , 3.4097522453e-15 , 3.44868075641e-15 , 3.4829247724e-15 , 3.52794717538e-15 , 3.47317658384e-15 , 3.48274296538e-15 , 3.4683000797e-15 , 3.44136351605e-15 , 3.44956082832e-15 , 3.37234682428e-15 , 3.43314422749e-15 , 3.41654316767e-15 , 3.43418130995e-15 , 3.44990893802e-15 , 3.36433409864e-15 , 3.44146680812e-15 , 3.4089 ...

# %%
#%%timeit
params = {"temp":6200, "logg":4.0, "Z":-0.2, "vsini":10, "vz":14, "logOmega":-19.4}
myModel.update_Model(params)
model_flux = myOrderModel.get_spectrum()[0]

# %%
myModel.evaluate()
# Out:
# Calling CovarianceMatrix.evaluate()
# ('Residuals are now', array([ -2.02774223e-13,  -2.07809628e-13,  -1.96242779e-13, ...,
#         -2.01193291e-13,  -1.92624739e-13,  -1.90238756e-13]))
# ('lnprob is now', -4679261.89333808)
# -4679261.8933380796

# %%
timeit myModel.evaluate()
# Out:
# 1000 loops, best of 3: 406 µs per loop

# %%
myOrderModel.update_Cov({"sigAmp": 1, "logAmp":-15 , "l":0.5})

# %%
timeit myModel.evaluate()
# Out:
# 1000 loops, best of 3: 952 µs per loop

# %%
#First pass at actually plotting the model
params = {"temp":6200, "logg":4.0, "Z":-0.2, "vsini":10, "vz":15, "logOmega":-20}
myModel.update_Model(params)

myOrderModel.update_Cheb(np.array([0, 0, 0]))
model_flux = myOrderModel.get_spectrum()

# %%
spec = myModel.get_data()
wl = spec.wls[0]
fl = spec.fls[0]

fig, ax = plt.subplots(nrows=2, figsize=(11,8), sharex=True)
ax[0].plot(wl, fl, "b")
l_model, = ax[0].plot(wl, model_flux, "r")
ax[0].set_ylabel("Data and Model")
l_resid, = ax[1].plot(wl, fl - model_flux, "b")
ax[1].set_xlabel(r"$\lambda$\AA")
ax[1].set_ylabel("Residuals")

#cov = myModel.OrderModels[0].get_Cov()[0].todense()

#fig2 = plt.figure()
#ax2 = fig2.add_subplot(111)
#im = ax2.imshow(cov, origin='upper', interpolation='none')

plt.show()

# %%
def update_model_plot(**kwargs):
    '''Take the kwargs, update the model and residuals'''
    
    #Update the model spectrum
    myModel.update_Model(kwargs)
    model_flux = myOrderModel.get_spectrum()
    l_model.set_ydata(model_flux)
    
    #Update the residuals
    residuals = fl - model_flux
    l_resid.set_ydata(residuals)
    
    #Find ymax and ymin and rescale
    ax[0].set_ylim(np.min([fl, model_flux]), np.max([fl, model_flux]))
    ax[1].set_ylim(np.min(fl - model_flux), np.max(fl - model_flux))
    
    #Redraw the plot
    fig.canvas.draw_idle()
    
    #Calculate and print the lnprob
    #print(myModel.evaluate())

# %%
def update_Cheb_plot(**kw):
    '''Take the kwargs, update the model and residuals'''
    
    p = np.array([kw['c1'], kw['c2'], kw['c3']])
    #Update the Chebyshev polynomial
    myOrderModel.update_Cheb(p)
    
    model_flux = myOrderModel.get_spectrum()
    l_model.set_ydata(model_flux)
    
    #Update the residuals
    l_resid.set_ydata(fl - model_flux)
    
    #Find ymax and ymin and rescale
    ax[0].set_ylim(np.min([fl, model_flux]), np.max([fl, model_flux]))
    ax[1].set_ylim(np.min(fl - model_flux), np.max(fl - model_flux))
    
    #Redraw the plot
    fig.canvas.draw_idle()
    
    #Calculate and print the lnprob
    #print(myModel.evaluate())

# %%
def update_Cov_plot(**kwargs):
    '''Take the kwargs, update the model and residuals'''
    
    #Update the covariance matrix
    myModel.update_Cov(kwargs)
    cov = myModel.get_Cov()[0].todense()
    
    #Replot the covariance matrix
    im.set_array(cov)
    
    #Redraw the plot
    fig2.canvas.draw_idle()
    
    #Calculate and print the lnprob
    print(myModel.evaluate())

# %%
print(myModel.evaluate())
# Out:
# -9.72154436305e+38

# %%
i = interact(update_model_plot,
         temp=(5500,6400, 10),
         logg=(3.5,5.0, 0.1),
         Z=(-1.0, 0.0, 0.1),
         #alpha=(0.0, 0.4, 0.05),
         vsini=(3, 10., 0.5),
         vz=(12,18, 0.1),
         #Av=(0.0,1.0, 0.05),
         logOmega=(-19.9,-19.5, 0.01),
         )

# %%
i = interact(update_Cheb_plot,
         c1=(-0.2, 0.2, 0.01),
         c2=(-0.2, 0.2, 0.01),
         c3=(-0.2, 0.2, 0.01),
         )
# Out:
# -9.72154436305e+38

# %%
i = interact(update_Cov_plot,
         sigAmp=(.5,1.5, 0.1),
         logAmp=(-15,-13, 0.2),
         l=(0.1, 1, 0.1),
         )
# Out:
# 72857.5012234

# %% [markdown]
# Good starting guesses:
# temp: 6100
# logg: 4.0
# Z: -0.5
# vsini: 6
# vz: 13.7
# log_Omega: -19.7
# alpha: 0.2

# %% [markdown]
# # Visualizing matrices from the MCMC run
#
# Use the multidimensional Gaussian code to draw samples from this covariance matrix and see if they look anything like the residuals.

# %%
def sparse_k_3_2(xs, amp, l):
    N = len(xs)
    offset = 0
    r0 = 6 * l
    diags = []
    while offset < N:
        #Pairwise calculate rs
        if offset == 0:
            rs = np.zeros_like(xs)
        else:
            rs = np.abs(xs[offset:] - xs[:-offset])
            k = np.empty_like(rs)
        if np.min(rs) >= r0:
            break
        k = (0.5 + 0.5 * np.cos(np.pi * rs/r0)) * amp**2 * (1 + np.sqrt(3) * rs/l) * np.exp(-np.sqrt(3) * rs/l)
        k[rs >= r0] = 0
        diags.append(k)
        offset += 1

    #Mirror the diagonals
    front = diags[1:].copy()
    front.reverse()
    diags = front + diags
    offsets = [i for i in range(-offset + 1, offset)]
    return sp.diags(diags, offsets, format="csc")

# %%
def sparse_k_1_2(xs, amp, l):
    N = len(xs)
    offset = 0
    r0 = 6 * l
    diags = []
    while offset < N:
        #Pairwise calculate rs
        if offset == 0:
            rs = np.zeros_like(xs)
        else:
            rs = np.abs(xs[offset:] - xs[:-offset])
            k = np.empty_like(rs)
        if np.min(rs) >= r0:
            break
        k = (0.5 + 0.5 * np.cos(np.pi * rs/r0)) * amp**2 * (rs/l)
        k[rs >= r0] = 0
        diags.append(k)
        offset += 1

    #Mirror the diagonals
    front = diags[1:].copy()
    front.reverse()
    diags = front + diags
    offsets = [i for i in range(-offset + 1, offset)]
    return sp.diags(diags, offsets, format="csc")

# %%
spec = myModel.get_data()
wl = spec.wls[0]

sigAmp = 0.97
#l = 0.18 #ang
l = 0.1 #ang
amp = 10**(-14.17)
sigma = myDataSpectrum.sigmas[0]
sigmaMat = sp.diags([sigma**2], [0], dtype=np.float64, format="csc")

mysparse = sparse_k_1_2(wl, amp, l) + sigAmp**2 * sigmaMat

# %%
spec = myModel.get_data()
wl = spec.wls[0]

sigAmp = 0.97
#l = 0.18 #ang
l = 0.1 #ang
amp = 10**(-14.17)
sigma = myDataSpectrum.sigmas[0]
sigmaMat = sp.diags([sigma**2], [0], dtype=np.float64, format="csc")

mysparse = sparse_k_3_2(wl, amp, l) + sigAmp**2 * sigmaMat

# %%
mydense = mysparse.todense()

# %%
fl_fake = np.random.multivariate_normal(np.zeros((len(wl),)), mydense)

# %%
model_flux = myOrderModel.get_spectrum()
#plt.plot(wl, (fl - model_flux)/sigma, "b")
plt.plot(wl, fl_fake, "g", lw=0.2)
plt.show()

# %%
fig = plt.figure()
plt.acorr(fl_fake)
plt.show()

# %%
fig = plt.figure()
plt.acorr(fl - model_flux)
plt.show()

# %%
residuals = fl - model_flux
fig = plt.figure()
plt.plot(np.correlate(residuals, residuals, mode='full')**2, ".")
plt.show()

# %% [markdown]
# # Determine parameterizations of covariance kernels

# %%
def k_3_2(r, l):
    return (1 + np.sqrt(3) * r/l) * np.exp(-np.sqrt(3) * r/l)

def k_5_2(r, l):
    return (1 + np.sqrt(5) * r/l + 5 * r**2/(3 * l**2)) * np.exp(- np.sqrt(5) * r/l)

def line(r, slope, l):
    '''
    Intercepts y axis at 1.0.
    
    '''
    return (1 - r)

# %%
fig = plt.figure()
rs = np.linspace(0, 10)
plt.plot(rs, k_3_2(rs, 1))
plt.plot(rs, k_3_2(rs, 10))
plt.plot(rs, (k_3_2(rs, 1) + 0.5*k_3_2(rs, 10))
plt.show()
